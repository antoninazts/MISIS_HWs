# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задание-1" data-toc-modified-id="Задание-1-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Задание 1</a></span></li><li><span><a href="#Задание-2" data-toc-modified-id="Задание-2-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Задание 2</a></span></li></ul></li><li><span><a href="#$corr(x,y)-=-\frac{\sum_i^N{(x_i-\bar{x})-(y_i-\bar{y})}}{std(x)-*-std(y)}-*-\frac{1}{N}$" data-toc-modified-id="$corr(x,y)-=-\frac{\sum_i^N{(x_i-\bar{x})-(y_i-\bar{y})}}{std(x)-*-std(y)}-*-\frac{1}{N}$-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>$corr(x,y) = \frac{\sum_i^N{(x_i-\bar{x}) (y_i-\bar{y})}}{std(x) * std(y)} * \frac{1}{N}$</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#$\sum---знак-\,-суммирования-\,-по-\,-членам-\,-вектора$" data-toc-modified-id="$\sum---знак-\,-суммирования-\,-по-\,-членам-\,-вектора$-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>$\sum - знак \, суммирования \, по \, членам \, вектора$</a></span></li><li><span><a href="#$std---стандартное-\,-отклонение$" data-toc-modified-id="$std---стандартное-\,-отклонение$-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>$std - стандартное \, отклонение$</a></span></li><li><span><a href="#$\bar{x}---среднее-\,-вектора$" data-toc-modified-id="$\bar{x}---среднее-\,-вектора$-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>$\bar{x} - среднее \, вектора$</a></span></li></ul></li><li><span><a href="#Задание-3" data-toc-modified-id="Задание-3-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Задание 3</a></span></li><li><span><a href="#Задание-4" data-toc-modified-id="Задание-4-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задание 4</a></span><ul class="toc-item"><li><span><a href="#Подзадание-1" data-toc-modified-id="Подзадание-1-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Подзадание 1</a></span></li><li><span><a href="#подзадание-2" data-toc-modified-id="подзадание-2-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>подзадание 2</a></span></li></ul></li><li><span><a href="#Задание-5" data-toc-modified-id="Задание-5-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Задание 5</a></span></li><li><span><a href="#Задание-6" data-toc-modified-id="Задание-6-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Задание 6</a></span></li></ul></li></ul></div>

# %%
from typing import Tuple
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, poisson
import scipy

# функции для генерации данных

def generate_sample_for_statistic_calculation(size: int = 10000) -> np.ndarray:
    rnd_mean = np.random.normal(5, 5, size=1)[0]
    rnd_std = np.random.poisson(5, size=1)[0]
    return norm(rnd_mean, rnd_std).rvs(size)


def correlation_data() -> Tuple[np.ndarray, np.ndarray]:
    sample1 = norm(0, 1).rvs(1000)
    noise = norm(0, 1).rvs(1000)
    sample2 = np.random.normal(0, 1, size=1)[0] * sample1 + np.random.normal(0, 1, size=1) + noise
    return sample1, sample2


def task3_data() -> np.ndarray:
    if np.random.random() < 0.8:
        return norm(0, 1).rvs(1000)
    else:
        return poisson(5).rvs(1000)
    
    
def task4_part1() -> Tuple[np.ndarray, np.ndarray]:
    rnd_mean1 = np.random.normal(5, 5, size=1)[0]
    rnd_std1 = np.random.poisson(5, size=1)[0]
    
    rnd_mean2 = np.random.normal(5, 5, size=1)[0]
    rnd_std2 = np.random.poisson(5, size=1)[0]
    
    sample1 = norm(rnd_mean1, rnd_std1).rvs(1000)
    sample2 = norm(rnd_mean2, rnd_std2).rvs(1000)
    
    print(f"sample1 mean: {sample1.mean()}")
    print(f"sample2 mean: {sample2.mean()}")
    

    return sample1, sample2

# %% [markdown]
# ### Задание 1

# %%
# Функция generate_sample_for_statistic_calculation() отдает выборку значений некоторого распределения.
# Посчитать общие статистики: 
#    минимум, максимум, медиана, среднее, дисперсия, стандратное отклонение, 0.25 и 0.75 квантили
# Используйте numpy и его функции агрегации.
# Для подсчета квантилей используйте функцию np.quantile(). Аргументы посмотрите в документации.
# Выведите все статистики по очереди на каждой строчке через print. 
# Посмотрите на цифры. Сделайте выводы о том, какие значения может принимать анализируемая случайная величина. 
# Как соотносятся между собой статистики? 
# Например, сильно ли отклоняются минимальные и максимальные значения от среднего?

values = generate_sample_for_statistic_calculation()

# %%
print("Минимум: ", np.min(values))
print("Максимум: ", np.max(values))
print("Среднее: ", np.mean(values))
print("Медиана: ", np.median(values))
print("Дисперсия: ", np.var(values))
print("Стандартное отклонение: ", np.std(values))
print("Квантиль 0.25: ", np.quantile(values, 0.25))
print("Квантиль 0.75: ", np.quantile(values, 0.75))
# Out:
# Минимум:  -39.724500384580594
# Максимум:  35.72348347871802
# Среднее:  -5.414253017135314
# Медиана:  -5.594983582726217
# Дисперсия:  81.89990349446276
# Стандартное отклонение:  9.049856545518429
# Квантиль 0.25:  -11.43821370092278
# Квантиль 0.75:  0.6217604728793484

# %% [markdown]
# Медиана и среднее близки по значениям, квантили равноудалены от медианы, значит распределение выборки близко к симметричному.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.grid()
plt.hist(values, bins=50)

plt.subplot(1,2,2)
plt.grid()
plt.violinplot(values, vert=False, showmeans=True, quantiles=[.25, .75])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dbe6bbf730>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x1dbe6bbf6a0>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dbe6bbfb50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dbe6bbfe80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dbe6bd11f0>,
#  'cquantiles': <matplotlib.collections.LineCollection at 0x1dbe6bd1520>}

# %% [markdown]
# ### Задание 2

# %%
# Корреляция
# Корреляция показывает линейную зависимость между величинами и может принимать значения от -1 до 1.
# 1 и -1 показывают сильную корреляцию. Значение близкое к нулю показывает то, что корреляции почти нет.
# Напишите функцию корреляции с помощью модуля numpy.
# Функция принимает 2 выборки. И возвращает одно число.
# Сравните по времени (функция %%timeit) работу вашей функции и функции np.corrcoef() модуля numpy

# Формула для расчет корреляции ниже:

# %% [markdown]
# ## $corr(x,y) = \frac{\sum_i^N{(x_i-\bar{x}) (y_i-\bar{y})}}{std(x) * std(y)} * \frac{1}{N}$
#
# #### $\sum - знак \, суммирования \, по \, членам \, вектора$
# #### $std - стандартное \, отклонение$
# #### $\bar{x} - среднее \, вектора$

# %%
sample1, sample2 = correlation_data()

# %%
def correlation(x, y):
    correlation = np.sum((x - np.mean(x)) * (y - np.mean(y))) / (np.std(x)*np.std(y)*len(x))
    return correlation

# %%
# %%timeit
correlation(sample1,sample2)
# Out:
# 91.9 µs ± 1.72 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
np.corrcoef(sample1,sample2)
# Out:
# 119 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Самописная функция примерно 20% быстрее, возможно, потому что встроенная функция работает по той же формуле, но долог ее вызов из библиотеки

# %% [markdown]
# ### Задание 3

# %%
# Код генерирует данные, которые вы должны проверить на нормальность распределения.
# Напишите код, который это выполняет.
# Определите нулевую гипотезу и альтернативную.
# Задайте уровень значимости.
# проведите тест и сделайте выводы на его основе.
# выведи все нужные для принятия решения результаты на экран

# %%
values = task3_data()

# %%
#H0: распределение нормальное
#H1: распределение отлично от нормального

from scipy.stats import shapiro

p = 0.05

p_value = shapiro(values).statistic

if p_value < p:
    print(f"p-value = {p_value}, Н0 отклонена, принимаем Н1: распределение отлично от нормального")
else:
    print(f"p-value = {p_value}, Н0 не отклонена: распределение нормально")
# Out:
# p-value = 0.9725577235221863, Н0 не отклонена: распределение нормально

# %%
plt.figure(figsize=(15,5))
plt.grid()
plt.violinplot(values, vert=False, showmeans=True, quantiles=[.25, .75])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dbe6dc4520>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x1dbe6dc4490>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dbe6dc4a60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dbe6dc4d90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dbe7356100>,
#  'cquantiles': <matplotlib.collections.LineCollection at 0x1dbe7356430>}

# %% [markdown]
# ### Задание 4

# %% [markdown]
# #### Подзадание 1

# %%
# проведите ttest на двух множествах (используйте ttest_ind метод из scipy.stats)
# выберите уровень значимости.
# определите нулевую и альтернативную гипотезы.
# получите p_value. Определите прокрасился ли тест или нет.
# сделайте выводы.
# выводите все нужные для анализа результаты на экран

# %%
sample1, sample2 = task4_part1()
# Out:
# sample1 mean: 2.245955341684079
# sample2 mean: 1.227956840036182

# %%
# H0: различий между множествами нет
# H1: различия между множествами есть

from scipy.stats import ttest_ind

p = 0.05

stat, p_value = ttest_ind(sample1, sample2)

if p_value < p:
    print(f"p-value = {p_value}, Н0 отклонена, принимаем Н1: различия между множествами есть")
else:
    print(f"p-value = {p_value}, Н0 не отклонена: различий между множествами нет")
# Out:
# p-value = 6.317736845883563e-08, Н0 отклонена, принимаем Н1: различия между множествами есть

# %%
plt.figure(figsize=(15, 5))
plt.plot()
plt.grid()
sns.kdeplot(sample1)
sns.kdeplot(sample2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### подзадание 2

# %%
# Подбрасывали игральную кость. Делали это 1000 раз. Получили следующие показания.
# Вопрос: является ли кость симметричной? То есть любая грань может выпасть одинаковое кол-во раз?
# возьмите функцию chisquare из scipy.stats и проведи проверку.
# выберите уровень значимости.
# определите нулевую и альтернативную гипотезы.
# получите p_value. Определите прокрасился ли тест или нет.
# сделайте выводы.

# После выводов проделайте следующее:
# Как должны были выпасть грани, чтобы тест показал противоположный результат? Запишите получившийся вариант

# %% [markdown]
# $$
# \begin{aligned}
# &\begin{array}{cccc}
# \hline Ребро & 1 & 2 & 3 & 4 & 5 & 6 \\
# \hline Кол-во \, выпаданий & 150 & 153 & 166 & 170 & 183 & 178 \\
# \hline
# \end{array}
# \end{aligned}
# $$

# %%
# H0: кость симметрична
# H1: кость не симметрична

from scipy.stats import chisquare

p = 0.05

stat, p_value = chisquare(np.array([150, 153, 166, 170, 183, 178]))

if p_value < p:
    print(f"p-value = {p_value}, Н0 отклонена, принимаем Н1: кость не симметрична")
else:
    print(f"p-value = {p_value}, Н0 не отклонена: кость симметрична")
# Out:
# p-value = 0.3886932697639033, Н0 не отклонена: кость симметрична

# %%
# Чтобы тест показал противоположный результат, увеличим, например, количество выпадений 6й грани 
# (то есть сделаем кость очевидно несимметричной) 

stat, p_value = chisquare(np.array([150, 153, 166, 170, 183, 278]))

if p_value < p:
    print(f"p-value = {p_value}, Н0 отклонена, принимаем Н1: кость не симметрична")
else:
    print(f"p-value = {p_value}, Н0 не отклонена: кость симметрична")
# Out:
# p-value = 3.5721407806356294e-12, Н0 отклонена, принимаем Н1: кость не симметрична

# %% [markdown]
# ### Задание 5

# %%
# Интегрирование. 
# Напишите функцию, которая определена на интервале от -10 до 10. 
# Функция на ваше усмотрение.
# Посчитайте интеграл (площадь под кривой) вашей функции.
# Проверьте себя либо аналитическим расчетом интеграла, либо воспользовавшись сервисом 
# https://www.integral-calculator.ru/

# %%
from scipy import integrate
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 100)
def y(x):
    return -x ** 2 + 100

integral, err = integrate.quad(y, -10, 10)

print("Интеграл функции y = x^2 + 100 на интервале (-10, 10) = ", integral)

plt.figure(figsize=(15,5))
plt.plot(x, y(x))
plt.grid(True)
# Out:
# Интеграл функции y = x^2 + 100 на интервале (-10, 10) =  1333.3333333333335

# %% [markdown]
# ### Задание 6

# %%
# Решите задачу интерполирования.
# У вас есть конечное число точек. Постройте на них функцию, которую хочется.
# Проведите на ней процедуру интерполяции. 
# Проверьте либо руками, либо с помощью питона результат работы вашей интерполяции 
# результат и выводы выведи на экран.

# %%
from scipy import interpolate

# %%
x = np.arange(-20, 20, 1)
y = np.cos(x)

f = interpolate.interp1d(x, y)

x1 = np.linspace(min(x), max(x), 100)
y1 = f(x1)

plt.figure(figsize=(15,5))
plt.grid(True)
plt.scatter(x, y)
plt.plot(x1, y1)
